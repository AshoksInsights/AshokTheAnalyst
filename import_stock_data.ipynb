# %%
import pandas as pd
import numpy as np
import yfinance as yf
import plotly.express as px
from talib.abstract import *
import talib
from talib import MA_Type

# %%
symbol = pd.read_csv('Symbols.csv')
tick=symbol.yf_symbol.values.tolist()

# %%
len(tick)
# Out:
# 50

# %%
df1=[]
for i in tick:
  df=yf.download(i,period='5y')
  df.reset_index(inplace=True)
  df=df.dropna()
  df['Range']=df['High']-df['Low']
  df['symbol']=i.split(".")[0]
  df['Change_%']=(df['Close'].pct_change())*100
  df['RSI'] = talib.RSI(df.Close,14)
  df['SMA'] = talib.SMA(df.Close)
  upper,middle,lower = talib.BBANDS(df.Close,matype=MA_Type.T3)
  df['BB_u'] = upper
  df['BB_m'] = middle
  df['BB_l'] = lower
  df1.append(df)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
df = pd.concat(df1)
df.reset_index(inplace=True)

# %%
infy = df[df['symbol']=="INFY"]

# %%
fig = px.line(infy,'Date','Close')
fig.show()

# %%
infy
# Out:
#        index       Date         Open         High          Low        Close  \
# 32084      0 2018-07-17   664.849976   674.750000   656.349976   663.950012
# 32085      1 2018-07-18   669.900024   671.700012   657.000000   661.275024
# 32086      2 2018-07-19   661.500000   665.950012   654.549988   658.349976
# 32087      3 2018-07-20   663.000000   683.575012   660.650024   674.049988
# 32088      4 2018-07-23   676.075012   684.000000   668.125000   677.974976
# ...      ...        ...          ...          ...          ...          ...
# 33313   1229 2023-07-11  1333.449951  1350.900024  1327.000000  1348.599976
# 33314   1230 2023-07-12  1351.000000  1351.900024  1327.000000  1333.300049
# 33315   1231 2023-07-13  1334.900024  1376.800049  1330.849976  1365.099976
# 33316   1232 2023-07-14  1380.650024  1430.000000  1380.650024  1425.949951
# 33317   1233 2023-07-17  1425.949951  1458.949951  1414.300049  1422.949951
#
# ...

# %%
upper,middle,lower = talib.BBANDS(df.Close,matype=MA_Type.T3)

# %%
upper
# Out:
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#             ...
# 61695    399.139743
# 61696    399.008544
# 61697    398.068855
# 61698    405.990698
# 61699    416.968578
# Length: 61700, dtype: float64
